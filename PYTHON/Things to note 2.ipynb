# %%
x = "hello world"
print(x)
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("Welldone Abass")
# Out:
# Welldone Abass
